# %%
a = 10

# %%
a+=10

# %%
a
# Out:
# 30

# %%
import sys

# %%
import os

# %%
print (sys.modules)
# Out:
# {'sys': <module 'sys' (built-in)>, 'builtins': <module 'builtins' (built-in)>, '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>, '_imp': <module '_imp' (built-in)>, '_thread': <module '_thread' (built-in)>, '_warnings': <module '_warnings' (built-in)>, '_weakref': <module '_weakref' (built-in)>, 'zipimport': <module 'zipimport' (built-in)>, '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>, '_io': <module 'io' (built-in)>, 'marshal': <module 'marshal' (built-in)>, 'nt': <module 'nt' (built-in)>, 'winreg': <module 'winreg' (built-in)>, 'encodings': <module 'encodings' from 'C:\\Users\\heave\\Anaconda3\\lib\\encodings\\__init__.py'>, 'codecs': <module 'codecs' from 'C:\\Users\\heave\\Anaconda3\\lib\\codecs.py'>, '_codecs': <module '_codecs' (built-in)>, 'encodings.aliases': <module 'encodings.aliases' from 'C:\\Users\\heave\\Anaconda3\\lib\\encodings\\aliases.py'>, 'encodings.utf_8': <module 'encodings.utf_8' from 'C:\\Users\\heave\\Anaconda3\
# ...

# %%
print(sys.path)
# Out:
# ['C:\\Users\\heave\\OneDrive\\文件\\GitHub\\Learing', 'C:\\Users\\heave\\Anaconda3\\python37.zip', 'C:\\Users\\heave\\Anaconda3\\DLLs', 'C:\\Users\\heave\\Anaconda3\\lib', 'C:\\Users\\heave\\Anaconda3', '', 'C:\\Users\\heave\\Anaconda3\\lib\\site-packages', 'C:\\Users\\heave\\Anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\heave\\Anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\heave\\Anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\heave\\Anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\heave\\.ipython']

# %%
import module1

# %%
module1.abc
# Out:
# 'i am a string'

# %%
module1.de
# Out:
# 568

# %%
def test(a,b,c=10,) :
    return(a+b+c, a-b+c, a+c-b)
    print (i, j, k)

# %%
test(1,4)
# Out:
# (15, 7, 7)

# %%
i,j,k=test(1,3,5)

# %%
print(i,j,k)
# Out:
# 9 3 3

# %%
type(test)
# Out:
# function

# %%
test(5,6,100)
# Out:
# 111
# 99
# -89

# %%
import module2

# %%
module2.add(1,2)
# Out:
# 3

# %%
from module2 import add

# %%
add(6,7)
# Out:
# 13

# %%
from module2 import abc
from module2 import de
from module2 import add

# %%
abc
# Out:
# 'i am a string'

# %%
de
# Out:
# 568

# %%
add
# Out:
# <function module2.add(a, b)>
